# %%
import pandas as pd

# Train split
train_url = "https://huggingface.co/datasets/talkpl-ai/TalkPlayData-Challenge-Dataset/resolve/main/data/train-00000-of-00001.parquet"

# Test split  
test_url = "https://huggingface.co/datasets/talkpl-ai/TalkPlayData-Challenge-Dataset/resolve/main/data/test-00000-of-00001.parquet"

df_train = pd.read_parquet(train_url)
df_test = pd.read_parquet(test_url)

# %%
import pandas as pd

splits = {'train': 'data/train-00000-of-00001.parquet', 'test': 'data/test-00000-of-00001.parquet'}
df = pd.read_parquet("hf://datasets/talkpl-ai/TalkPlayData-Challenge-Dataset/" + splits["train"])
# Out:
# ---------------------------------------------------------------------------
# ConnectError                              Traceback (most recent call last)
# File ~/Workspace/03_Learn/RecSys2026/.venv/lib/python3.12/site-packages/httpx/_transports/default.py:101, in map_httpcore_exceptions()
#     100 try:
# --> 101     yield
#     102 except Exception as exc:
#
# File ~/Workspace/03_Learn/RecSys2026/.venv/lib/python3.12/site-packages/httpx/_transports/default.py:250, in HTTPTransport.handle_request(self, request)
#     249 with map_httpcore_exceptions():
# --> 250     resp = self._pool.handle_request(req)
#     252 assert isinstance(resp.stream, typing.Iterable)
#
# File ~/Workspace/03_Learn/RecSys2026/.venv/lib/python3.12/site-packages/httpcore/_sync/connection_pool.py:256, in ConnectionPool.handle_request(self, request)
#     255     self._close_connections(closing)
# --> 256     raise exc from None
#     258 # Return the response. Note that in this case we still have to manage
# ...
